# %%
# variable & string
a=18
print("Iam ",a,"years old");
# Out:
# Iam  18 years old

# %%
#Arithmetic  operations of two integer variables
a=int(input("Enter a number"))
b=int(input("Enter other number"))
print("Sum is",a+b)
print("Difference is",a-b)
print("Product is",a*b)
print("Quotient is",a/b)
print("Remainder is",a%b)
print("Power of a to b",a**b)
print("Floor division",a//b)
# Out:
# Enter a number5
# Enter other number3
# Sum is 8
# Difference is 2
# Product is 15
# Quotient is 1.6666666666666667
# Remainder is 2
# Power of a to b 125
# Floor division 1

# %%
#take a number from the user which is the salary .if the salary is more than 50000,there is a 10% tax deduction.print the final salary
s=int(input("enter salary"))
if(s>=50000):
  tax=s*(10/100)
  s=s-tax
  print("final salary is:",s)
else:
    print("your salary is less than 50000 no tax deduction")
# Out:
# enter salary25000
# your salary is less than 50000 no tax deduction

# %%
#Take salary from the user .If the salary is more than 50k there is a 10% tax. Print his final salary.
s=int(input("Enter salary"))
if(s>=50000):
  print("Your final salary is",s-((0.1)*s))
else:
  print("There is no tax deduction")
# Out:
# Enter salary60000
# Your final salary is 54000.0

# %%
#Get the salary  from the user if the salary is >= 50k apply 10% tax deduction .if the salary is < 50k apply 5% tax ,if the salary > 70kapply 12% tax if salary exceeds 1L print you are promoted

s=int(input("Enter salary"))
if(s<50000):
 print("Your final salary is",s-((0.05)*s))
elif(s<=70000):
 print("Your final salary is",s-((0.1)*s))
elif(s<=100000):
 print("Your final salary is",s-((0.12)*s))
else:
 print("You are promoted")
# Out:
# Enter salary95000
# Your final salary is 83600.0

# %%
#for loop:
n=int(input("Enter n value: "))
r=range(1,11)
for i in r:
 print(n ,"X", i , "=", n*i)
# Out:
# Enter n value: 5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
a=int(input("Enter a value"))
i=1
while(i<11):
  print(a ,"X", i , "=", a*i)
  i=i+1
# Out:
# Enter a value8
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# 8 X 10 = 80

# %%
#Create a list 10 random integer elements and print their squares and save them in a new list
l=[1,209,123,4,53,656,73,8,9,10]
l2=[]
for i in l:
 l2.append(i*i)
 print(l2)
# Out:
# [1]
# [1, 43681]
# [1, 43681, 15129]
# [1, 43681, 15129, 16]
# [1, 43681, 15129, 16, 2809]
# [1, 43681, 15129, 16, 2809, 430336]
# [1, 43681, 15129, 16, 2809, 430336, 5329]
# [1, 43681, 15129, 16, 2809, 430336, 5329, 64]
# [1, 43681, 15129, 16, 2809, 430336, 5329, 64, 81]
# [1, 43681, 15129, 16, 2809, 430336, 5329, 64, 81, 100]

# %%
#Take the salary from the user if it salary < 50k 10% tax otherwise 15% tax
s=[20000,40000,70000,90000]
l3=[i-(0.1*i) if i<50000 else i-(0.15*i) for i in s]
print(l3)
# Out:
# [18000.0, 36000.0, 59500.0, 76500.0]

# %%
#To print required details
dict2={"Dept":'CSE','details':{'year':2,'Sec':'D',"Strength":71}}
print("Year is ",dict2["details"]["year"])
print("Section is",dict2["details"]["Sec"])
print("Count is ",dict2["details"]["Strength"])
# Out:
# Year is  2
# Section is D
# Count is  71

# %%
import numpy as np

# %%
e=np.arange(8,1000,8)
print(e)
# Out:
# [  8  16  24  32  40  48  56  64  72  80  88  96 104 112 120 128 136 144
#  152 160 168 176 184 192 200 208 216 224 232 240 248 256 264 272 280 288
#  296 304 312 320 328 336 344 352 360 368 376 384 392 400 408 416 424 432
#  440 448 456 464 472 480 488 496 504 512 520 528 536 544 552 560 568 576
#  584 592 600 608 616 624 632 640 648 656 664 672 680 688 696 704 712 720
#  728 736 744 752 760 768 776 784 792 800 808 816 824 832 840 848 856 864
#  872 880 888 896 904 912 920 928 936 944 952 960 968 976 984 992]

# %%
#Spliting a range of numbers having common difference
q=np.linspace(3,2,12)
print(q)
# Out:
# [3.         2.90909091 2.81818182 2.72727273 2.63636364 2.54545455
#  2.45454545 2.36363636 2.27272727 2.18181818 2.09090909 2.        ]

# %% [markdown]
# TUPLE

# %%
x=[1,3,4,5,6]
y=[9,4,5,2,8]
plt.plot(x,y)  #line graph
plt.title("My first plot")
plt.xlabel('x value')
plt.ylabel('y value')
#tittl,labels,legend,color,width,markers!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-543f724f6d74> in <cell line: 3>()
#       1 x=[1,3,4,5,6]
#       2 y=[9,4,5,2,8]
# ----> 3 plt.plot(x,y)  #line graph
#       4 plt.title("My first plot")
#       5 plt.xlabel('x value')
#
# NameError: name 'plt' is not defined

# %%
#creating
tuple1 = ("apple", "banana", "cherry")
print(tuple1)
# Out:
# ('apple', 'banana', 'cherry')

# %%
#acess the tuple
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
#update the tuple
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = list(y)

print(x)
# Out:
# ['apple', 'kiwi', 'cherry']

# %%
#loop
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'apple', 'banana', 'orange', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'apple', 'cherry'}
